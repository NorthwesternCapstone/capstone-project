# %%
import pandas as pd
import numpy as np
import dask.dataframe as dd 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
import os
import re
import random
import datetime
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import utils
from sklearn import metrics, svm
from math import sqrt
from sklearn.metrics import r2_score
import xgboost as xgb
plt.style.use('fivethirtyeight')

# %%
# load the properties data
properties = pd.read_csv('properties_2016.csv', low_memory=False)
pd.options.display.max_columns = None
print properties.shape
properties.head()
# Out:
# (2985217, 58)
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# 0                NaN         NaN                       NaN
# 1                NaN         NaN                       NaN
# 2                NaN         NaN                       NaN
# 3                NaN         NaN                       NaN
# 4                NaN         NaN                       NaN
#
#    calculatedfinishedsquarefeet  finishedsquarefeet12  finishedsquarefeet13  \
# 0                           NaN                   NaN                   NaN
# 1                           NaN                   NaN                   NaN
# 2                       73026.0                   NaN                   NaN
# 3                        5068.0                   NaN                   NaN
# 4                        1776.0                   NaN                   NaN
#
#    finishedsquarefeet15  finishedsquarefeet50  finishedsquarefeet6    fips  \
# 0                   NaN                   NaN                  NaN  6037.0
# 1                   NaN                   NaN                  NaN  6037.0
# 2               73026.0                   NaN                  NaN  6037.0
# 3                5068.0                   NaN                  NaN  6037.0
# 4                1776.0                   NaN                  NaN  6037.0
#
#    fireplacecnt  fullbathcnt  garagecarcnt  garagetotalsqft hashottuborspa  \
# 0           NaN          NaN           NaN              NaN            NaN
# 1           NaN          NaN           NaN              NaN            NaN
# 2           NaN          NaN           NaN              NaN            NaN
# 3           NaN          NaN           NaN              NaN            NaN
# 4           NaN          NaN           NaN              NaN            NaN
#
#    heatingorsystemtypeid    latitude    longitude  lotsizesquarefeet  poolcnt  \
# 0                    NaN  34144442.0 -118654084.0            85768.0      NaN
# 1                    NaN  34140430.0 -118625364.0             4083.0      NaN
# 2                    NaN  33989359.0 -118394633.0            63085.0      NaN
# 3                    NaN  34148863.0 -118437206.0             7521.0      NaN
# 4                    NaN  34194168.0 -118385816.0             8512.0      NaN
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          NaN
# 3          NaN           NaN          NaN          NaN
# 4          NaN           NaN          NaN          NaN
#
#   propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# 0                      010D                  269.0                NaN
# 1                      0109                  261.0             LCA11*
# 2                      1200                   47.0               LAC2
# 3                      1200                   47.0               LAC2
# 4                      1210                   31.0               LAM1
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.037800e+07       37688.0          3101.0                   NaN
# 1            6.037800e+07       37688.0          3101.0                   NaN
# 2            6.037703e+07       51617.0          3101.0                   NaN
# 3            6.037141e+07       12447.0          3101.0               27080.0
# 4            6.037123e+07       12447.0          3101.0               46795.0
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0      96337.0      0.0          NaN                  NaN
# 1      96337.0      0.0          NaN                  NaN
# 2      96095.0      0.0          NaN                  NaN
# 3      96424.0      0.0          NaN                  NaN
# 4      96450.0      0.0          NaN                  NaN
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                     NaN      NaN                 NaN                 NaN
# 1                     NaN      NaN                 NaN                 NaN
# 2                     NaN      2.0                 NaN                 NaN
# 3                     NaN      NaN                 NaN                 NaN
# 4                     NaN      1.0                 NaN                 NaN
#
#    yearbuilt  numberofstories fireplaceflag  structuretaxvaluedollarcnt  \
# 0        NaN              NaN           NaN                         NaN
# 1        NaN              NaN           NaN                         NaN
# 2        NaN              NaN           NaN                    650756.0
# 3     1948.0              1.0           NaN                    571346.0
# 4     1947.0              NaN           NaN                    193796.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0                9.0          2015.0                    9.0        NaN
# 1            27516.0          2015.0                27516.0        NaN
# 2          1413387.0          2015.0               762631.0   20800.37
# 3          1156834.0          2015.0               585488.0   14557.57
# 4           433491.0          2015.0               239695.0    5725.17
#
#   taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0                NaN                 NaN                  NaN
# 1                NaN                 NaN                  NaN
# 2                NaN                 NaN                  NaN
# 3                NaN                 NaN                  NaN
# 4                NaN                 NaN                  NaN

# %%
# Rename variables
properties.rename(index=str,columns={
"parcelid" : "id_parcel",
"basementsqft" : "area_basement",
"yearbuilt" : 'build_year',
"yardbuildingsqft17" : "area_patio",
"yardbuildingsqft26" : "area_shed",
"poolsizesum" : "area_pool",
"lotsizesquarefeet" : "lot_size",
"garagetotalsqft" : "area_garage",
"finishedfloor1squarefeet" : "area_firstfloor_finished",
"calculatedfinishedsquarefeet" : "area_total_calc",
"finishedsquarefeet6" : "area_base",
"finishedsquarefeet12" : "area_finished_living",
"finishedsquarefeet13" : "area_perimeter",
"finishedsquarefeet15" : "area_total_finished",
"finishedsquarefeet50" : "area_other",
"unitcnt" : "unit_count",
"numberofstories" : "number_of_stories",
"roomcnt" : "room_count",
"bathroomcnt" : "bath_count",
"bedroomcnt" : "bedroom_count",
"calculatedbathnbr" : "bath_count_calc",
"fullbathcnt" : "bath_full_count",
"threequarterbathnbr" : "bath_3qtrs_count",
"fireplacecnt" : "fireplace_count",
"poolcnt" : "pool_count",
"garagecarcnt" : "garage_stalls_count",
"regionidcounty" : "region_county",
"regionidcity" : "region_city",
"regionidzip" : "region_zip",
"regionidneighborhood" : "region_neighbor",
"taxvaluedollarcnt" : "home_value",
"structuretaxvaluedollarcnt" : "tax_building",
"landtaxvaluedollarcnt" : "tax_land",
"taxamount" : "tax_property",
"assessmentyear" : "tax_year",
"taxdelinquencyflag" : "tax_delinquency",
"taxdelinquencyyear" : "tax_delinquency_year",
"propertyzoningdesc" : "zoning_property",
"propertylandusetypeid" : "zoning_land_use",
"propertycountylandusecode" : "zoning_land_use_county",
"fireplaceflag" : "fireplace",
"hashottuborspa" : "tub",
"buildingqualitytypeid" : "bldg_quality",
"buildingclasstypeid" : "bldg_framing",
"typeconstructiontypeid" : "bldg_material",
"decktypeid" : "deck_type",
"storytypeid" : "story_type",
"airconditioningtypeid" : "airconditioning",
"architecturalstyletypeid" : "architectural_style"
},inplace=True)

# %%
# DATA TRANSFORMATIONS

# Calculated variables
properties['property_age'] = 2018 - properties['build_year']+1
properties['length_tax_delinq'] = 2018 - properties['tax_delinquency_year']+1
properties['total_rooms'] = properties['bath_count_calc'] + properties['bedroom_count']

# Dummy variables
properties['garage_yn'] = np.where((properties['garage_stalls_count'] > 0) | (properties['area_garage'] > 0),1,0)
properties['ac_yn'] = (properties['airconditioning']!=5)*1
properties['heat_yn'] = (properties['heatingorsystemtypeid']!=13)*1

properties['property_type'] = properties.zoning_land_use.replace({31 : "Mixed", 46 : "Other", 47 : "Mixed",
      246 : "Mixed", 247 : "Mixed", 248 : "Mixed",
      260 : "Home", 261 : "Home", 262 : "Home",
      263 : "Home", 264 : "Home", 265 : "Home",
      266 : "Home", 267 : "Home", 268 : "Home",
      269 : "Not Built", 270 : "Home", 271 : "Home",
      273 : "Home", 274 : "Other", 275 : "Home",
      276 : "Home", 279 : "Home", 290 : "Not Built",
      291 : "Not Built" }) 

properties['single_family_home'] = np.where(properties['zoning_land_use']==261, 1,0)

# Region density variables
properties['coords'] = properties['latitude']/(10^6) + properties['longitude']/(10^6)
zip_count = properties['region_zip'].value_counts().to_dict()
properties['zip_counts'] = properties['region_zip'].map(zip_count)
city_count = properties['region_city'].value_counts().to_dict()
properties['city_counts'] = properties['region_city'].map(city_count)
county_count = properties['region_county'].value_counts().to_dict()
properties['county_counts'] = properties['region_county'].map(county_count)

properties.drop(columns=['heatingorsystemtypeid','zoning_land_use',
                         'airconditioning','tax_delinquency_year','story_type','pooltypeid2',
                         'pooltypeid7','pooltypeid10'])

# Log variables 
properties['log_area_total_calc'] = np.log(properties['area_total_calc'].fillna(properties['area_total_calc'].median()))
properties['log_area_finished_living'] = np.log(properties['area_finished_living'].fillna(properties['area_finished_living'].median()))
properties['log_area_firstfloor_finished'] = np.log(properties['area_firstfloor_finished'])

properties.head()
# Out:
#    id_parcel  airconditioning  architectural_style  area_basement  bath_count  \
# 0   10754147              NaN                  NaN            NaN         0.0
# 1   10759547              NaN                  NaN            NaN         0.0
# 2   10843547              NaN                  NaN            NaN         0.0
# 3   10859147              NaN                  NaN            NaN         0.0
# 4   10879947              NaN                  NaN            NaN         0.0
#
#    bedroom_count  bldg_framing  bldg_quality  bath_count_calc  deck_type  \
# 0            0.0           NaN           NaN              NaN        NaN
# 1            0.0           NaN           NaN              NaN        NaN
# 2            0.0           NaN           NaN              NaN        NaN
# 3            0.0           3.0           7.0              NaN        NaN
# 4            0.0           4.0           NaN              NaN        NaN
#
#    area_firstfloor_finished  area_total_calc  area_finished_living  \
# 0                       NaN              NaN                   NaN
# 1                       NaN              NaN                   NaN
# 2                       NaN          73026.0                   NaN
# 3                       NaN           5068.0                   NaN
# 4                       NaN           1776.0                   NaN
#
#    area_perimeter  area_total_finished  area_other  area_base    fips  \
# 0             NaN                  NaN         NaN        NaN  6037.0
# 1             NaN                  NaN         NaN        NaN  6037.0
# 2             NaN              73026.0         NaN        NaN  6037.0
# 3             NaN               5068.0         NaN        NaN  6037.0
# 4             NaN               1776.0         NaN        NaN  6037.0
#
#    fireplace_count  bath_full_count  garage_stalls_count  area_garage  tub  \
# 0              NaN              NaN                  NaN          NaN  NaN
# 1              NaN              NaN                  NaN          NaN  NaN
# 2              NaN              NaN                  NaN          NaN  NaN
# 3              NaN              NaN                  NaN          NaN  NaN
# 4              NaN              NaN                  NaN          NaN  NaN
#
#    heatingorsystemtypeid    latitude    longitude  lot_size  pool_count  \
# 0                    NaN  34144442.0 -118654084.0   85768.0         NaN
# 1                    NaN  34140430.0 -118625364.0    4083.0         NaN
# 2                    NaN  33989359.0 -118394633.0   63085.0         NaN
# 3                    NaN  34148863.0 -118437206.0    7521.0         NaN
# 4                    NaN  34194168.0 -118385816.0    8512.0         NaN
#
#    area_pool  pooltypeid10  pooltypeid2  pooltypeid7 zoning_land_use_county  \
# 0        NaN           NaN          NaN          NaN                   010D
# 1        NaN           NaN          NaN          NaN                   0109
# 2        NaN           NaN          NaN          NaN                   1200
# 3        NaN           NaN          NaN          NaN                   1200
# 4        NaN           NaN          NaN          NaN                   1210
#
#    zoning_land_use zoning_property  rawcensustractandblock  region_city  \
# 0            269.0             NaN            6.037800e+07      37688.0
# 1            261.0          LCA11*            6.037800e+07      37688.0
# 2             47.0            LAC2            6.037703e+07      51617.0
# 3             47.0            LAC2            6.037141e+07      12447.0
# 4             31.0            LAM1            6.037123e+07      12447.0
#
#    region_county  region_neighbor  region_zip  room_count  story_type  \
# 0         3101.0              NaN     96337.0         0.0         NaN
# 1         3101.0              NaN     96337.0         0.0         NaN
# 2         3101.0              NaN     96095.0         0.0         NaN
# 3         3101.0          27080.0     96424.0         0.0         NaN
# 4         3101.0          46795.0     96450.0         0.0         NaN
#
#    bath_3qtrs_count  bldg_material  unit_count  area_patio  area_shed  \
# 0               NaN            NaN         NaN         NaN        NaN
# 1               NaN            NaN         NaN         NaN        NaN
# 2               NaN            NaN         2.0         NaN        NaN
# 3               NaN            NaN         NaN         NaN        NaN
# 4               NaN            NaN         1.0         NaN        NaN
#
#    build_year  number_of_stories fireplace  tax_building  home_value  \
# 0         NaN                NaN       NaN           NaN         9.0
# 1         NaN                NaN       NaN           NaN     27516.0
# 2         NaN                NaN       NaN      650756.0   1413387.0
# 3      1948.0                1.0       NaN      571346.0   1156834.0
# 4      1947.0                NaN       NaN      193796.0    433491.0
#
#    tax_year  tax_land  tax_property tax_delinquency  tax_delinquency_year  \
# 0    2015.0       9.0           NaN             NaN                   NaN
# 1    2015.0   27516.0           NaN             NaN                   NaN
# 2    2015.0  762631.0      20800.37             NaN                   NaN
# 3    2015.0  585488.0      14557.57             NaN                   NaN
# 4    2015.0  239695.0       5725.17             NaN                   NaN
#
#    censustractandblock  property_age  length_tax_delinq  total_rooms  \
# 0                  NaN           NaN                NaN          NaN
# 1                  NaN           NaN                NaN          NaN
# 2                  NaN           NaN                NaN          NaN
# 3                  NaN          71.0                NaN          NaN
# 4                  NaN          72.0                NaN          NaN
#
#    garage_yn  ac_yn  heat_yn property_type  single_family_home        coords  \
# 0          0      1        1     Not Built                   0 -7.042470e+06
# 1          0      1        1          Home                   1 -7.040411e+06
# 2          0      1        1         Mixed                   0 -7.033773e+06
# 3          0      1        1         Mixed                   0 -7.024029e+06
# 4          0      1        1         Mixed                   0 -7.015971e+06
#
#    zip_counts  city_counts  county_counts  log_area_total_calc  \
# 0      8496.0       7506.0      2009362.0             7.360104
# 1      8496.0       7506.0      2009362.0             7.360104
# 2      9437.0      11686.0      2009362.0            11.198571
# 3      7916.0     670925.0      2009362.0             8.530702
# 4      7725.0     670925.0      2009362.0             7.482119
#
#    log_area_finished_living  log_area_firstfloor_finished
# 0                  7.338888                           NaN
# 1                  7.338888                           NaN
# 2                  7.338888                           NaN
# 3                  7.338888                           NaN
# 4                  7.338888                           NaN

# %%
# Trim top and bottom 1% of values
properties['log_home_value'] = np.log(properties['home_value']+0.00001)
high = np.percentile((properties['log_home_value'].dropna()),99)
low  = np.percentile((properties['log_home_value'].dropna()),1)
properties1 = properties[(properties['log_home_value'] > low) & (properties['log_home_value'] < high)].copy()
print properties1.shape
# Out:
# (2883810, 74)

# %%
# Split data into training and validation
from xgboost import XGBRegressor
data = properties1.select_dtypes(exclude=[object]).copy()
data.fillna(-1,inplace=True)
data['target'] = properties1['home_value']

X = data.drop(['id_parcel','tax_building','home_value','log_home_value','target','tax_property', 'bath_count', 'bedroom_count','bath_count_calc','bath_full_count',
               'longitude', 'latitude','coords','rawcensustractandblock','censustractandblock','build_year'],axis=1)
y = data['target']

xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
# Run XGBoost model
model = XGBRegressor(n_estimators = 100,
                     learning_rate = 0.05,
                     max_depth = 10,
                     min_child_weight = 5)
eval_set = [(xtrain, ytrain), (xtest, ytest)]
# %time model.fit(xtrain, ytrain, early_stopping_rounds=10, eval_metric=["mae"], eval_set=eval_set, verbose=True)
results = model.evals_result()
# Out:
# [0]	validation_0-mae:364274	validation_1-mae:363695
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 10 rounds.
# [1]	validation_0-mae:346074	validation_1-mae:345525
# [2]	validation_0-mae:328783	validation_1-mae:328263
# [3]	validation_0-mae:312357	validation_1-mae:311862
# [4]	validation_0-mae:296752	validation_1-mae:296283
# [5]	validation_0-mae:281930	validation_1-mae:281483
# [6]	validation_0-mae:267850	validation_1-mae:267426
# [7]	validation_0-mae:254476	validation_1-mae:254073
# [8]	validation_0-mae:241774	validation_1-mae:241391
# [9]	validation_0-mae:229710	validation_1-mae:229348
# [10]	validation_0-mae:218252	validation_1-mae:217911
# [11]	validation_0-mae:207373	validation_1-mae:207050
# [12]	validation_0-mae:197045	validation_1-mae:196741
# [13]	validation_0-mae:187239	validation_1-mae:186954
# [14]	validation_0-mae:177932	validation_1-mae:177668
# [15]	validation_0-mae:169102	validation_1-mae:168856
# [16]	validation_0-mae:160724	validation_1-mae:160499
# [17]	validation_0-mae:152781	validation_1-mae:152577
# [18]	validation_0-mae:145250	validation_1-mae:145066
# [19]	validation_0-mae:138115	validation_1-mae:137952
# [20]	validation_0-mae:131357	validation_1-mae:131215
# [21]	validation_0-mae:124960	validation_1-mae:124836
# [22]	validation_0-mae:118907	validation_1-mae:118803
# [23]	validation_0-mae:113182	validation_1-mae:113096
# [24]	validation_0-mae:107770	validation_1-mae:107703
# [25]	validation_0-mae:102657	validation_1-mae:102609
# [26]	validation_0-mae:97834.6	validation_1-mae:97808.3
# [27]	validation_0-mae:93282	validation_1-mae:93274.8
# [28]	validation_0-mae:88991.7	validation_1-mae:89004.6
# [29]	validation_0-mae:84949.4	validation_1-mae:84984.8
# [30]	validation_0-mae:81148.7	validation_1-mae:81205
# [31]	validation_0-mae:77579.1	validation_1-mae:77657.6
# [32]	validation_0-mae:74234.6	validation_1-mae:74336.7
# [33]	validation_0-mae:71093	validation_1-mae:71218.6
# [34]	validation_0-mae:68156.4	validation_1-mae:68305.3
# [35]	validation_0-mae:65402.5	validation_1-mae:65574.7
# [36]	validation_0-mae:62835.1	validation_1-mae:63030.7
# [37]	validation_0-mae:60434.5	validation_1-mae:60652.5
# [38]	validation_0-mae:58204.1	validation_1-mae:58446.1
# [39]	validation_0-mae:56129.1	validation_1-mae:56392.7
# [40]	validation_0-mae:54199.8	validation_1-mae:54484.1
# [41]	validation_0-mae:52407.7	validation_1-mae:52712.2
# [42]	validation_0-mae:50746	validation_1-mae:51071.4
# [43]	validation_0-mae:49203.8	validation_1-mae:49548.6
# [44]	validation_0-mae:47777.2	validation_1-mae:48143.2
# [45]	validation_0-mae:46458.8	validation_1-mae:46845
# [46]	validation_0-mae:45238.5	validation_1-mae:45645.8
# [47]	validation_0-mae:44110.4	validation_1-mae:44539
# [48]	validation_0-mae:43080.6	validation_1-mae:43529.1
# [49]	validation_0-mae:42126	validation_1-mae:42593.5
# [50]	validation_0-mae:41250.4	validation_1-mae:41736.4
# [51]	validation_0-mae:40450.8	validation_1-mae:40955.3
# [52]	validation_0-mae:39711.7	validation_1-mae:40234.3
# [53]	validation_0-mae:39032.7	validation_1-mae:39572
# [54]	validation_0-mae:38409.8	validation_1-mae:38965.1
# [55]	validation_0-mae:37843.7	validation_1-mae:38414.7
# [56]	validation_0-mae:37323	validation_1-mae:37910.2
# [57]	validation_0-mae:36852.2	validation_1-mae:37453.9
# [58]	validation_0-mae:36424.7	validation_1-mae:37041.3
# [59]	validation_0-mae:36032.5	validation_1-mae:36664
# [60]	validation_0-mae:35676	validation_1-mae:36319.6
# [61]	validation_0-mae:35355	validation_1-mae:36012.2
# [62]	validation_0-mae:35058.9	validation_1-mae:35729
# [63]	validation_0-mae:34789.3	validation_1-mae:35473
# [64]	validation_0-mae:34542.3	validation_1-mae:35236.5
# [65]	validation_0-mae:34317.2	validation_1-mae:35023.4
# [66]	validation_0-mae:34117.1	validation_1-mae:34833.7
# [67]	validation_0-mae:33938.4	validation_1-mae:34667.5
# [68]	validation_0-mae:33779.7	validation_1-mae:34519.2
# [69]	validation_0-mae:33631.4	validation_1-mae:34382.8
# [70]	validation_0-mae:33489.9	validation_1-mae:34251.3
# [71]	validation_0-mae:33365.5	validation_1-mae:34138.1
# [72]	validation_0-mae:33258.9	validation_1-mae:34040.4
# [73]	validation_0-mae:33156.6	validation_1-mae:33949.1
# [74]	validation_0-mae:33062.7	validation_1-mae:33864
# [75]	validation_0-mae:32977.1	validation_1-mae:33787.2
# [76]	validation_0-mae:32902.4	validation_1-mae:33720.8
# [77]	validation_0-mae:32827.8	validation_1-mae:33655.4
# [78]	validation_0-mae:32767	validation_1-mae:33603.9
# [79]	validation_0-mae:32703.7	validation_1-mae:33549
# [80]	validation_0-mae:32654.9	validation_1-mae:33508.7
# [81]	validation_0-mae:32610.7	validation_1-mae:33471.4
# [82]	validation_0-mae:32562.1	validation_1-mae:33430.5
# [83]	validation_0-mae:32528.3	validation_1-mae:33403.4
# [84]	validation_0-mae:32493	validation_1-mae:33374.8
# [85]	validation_0-mae:32462.3	validation_1-mae:33351.6
# [86]	validation_0-mae:32430.1	validation_1-mae:33326.1
# [87]	validation_0-mae:32403.3	validation_1-mae:33305.7
# [88]	validation_0-mae:32375.6	validation_1-mae:33284.4
# [89]	validation_0-mae:32342.4	validation_1-mae:33257.6
# [90]	validation_0-mae:32317.8	validation_1-mae:33239.1
# [91]	validation_0-mae:32289.5	validation_1-mae:33219.2
# [92]	validation_0-mae:32261.1	validation_1-mae:33196.7
# [93]	validation_0-mae:32244.2	validation_1-mae:33185.4
# [94]	validation_0-mae:32220.8	validation_1-mae:33167.6
# [95]	validation_0-mae:32189.8	validation_1-mae:33143.5
# [96]	validation_0-mae:32173.7	validation_1-mae:33132.8
# [97]	validation_0-mae:32155.9	validation_1-mae:33121.4
# [98]	validation_0-mae:32145	validation_1-mae:33116.2
# [99]	validation_0-mae:32122	validation_1-mae:33098.9
# CPU times: user 22min 2s, sys: 40.7 s, total: 22min 43s
# Wall time: 22min 43s

# %%
# Model learning curve 
fig, ax = plt.subplots()
rounds = len(results['validation_0']['mae'])
x_axis = range(0, rounds)
ax.plot(x_axis, results['validation_0']['mae'], 'b', linewidth=2, label='Training')
ax.plot(x_axis, results['validation_1']['mae'], 'g', linewidth=2, label='Validation')
ax.legend()
plt.xlabel("Number of trees")
plt.ylabel('Classification Error (MAE)')
plt.title('XGBoost learning curve')
plt.show()

# %%
# Model learning curve 2
fig, ax = plt.subplots()
rounds = len(results['validation_0']['mae'])
x_axis = range(0, rounds)
ax.plot(x_axis, results['validation_0']['mae'], 'b', linewidth=2, label='Training')
ax.plot(x_axis, results['validation_1']['mae'], 'g', linewidth=2, label='Validation')
ax.legend()
plt.ylim(25000,45000)
plt.xlabel("Number of trees")
plt.ylabel('Classification Error (MAE)')
plt.title('XGBoost learning curve')
plt.show()

# %%
print("XGBoost MAE (Training):",np.mean(np.abs(model.predict(xtrain)-ytrain)))
print("XGBoost MAE (Validation):",np.mean(np.abs(model.predict(xtest)-ytest)))

r2 = r2_score(ytest, model.predict(xtest))
print("R2: %.4f" % r2)
# Out:
# ('XGBoost MAE (Training):', 32122.01599035525)
# ('XGBoost MAE (Validation):', 33098.95030067959)
# R2: 0.9645

# %%
# Feature Importance Plot
from xgboost import plot_importance
plot_importance(model, max_num_features=10)
plt.show()

# %%
model.get_booster().get_score()
# Out:
# {'airconditioning': 1081,
#  'area_base': 548,
#  'area_basement': 120,
#  'area_finished_living': 2615,
#  'area_firstfloor_finished': 876,
#  'area_garage': 1321,
#  'area_other': 247,
#  'area_patio': 255,
#  'area_perimeter': 14,
#  'area_pool': 103,
#  'area_shed': 25,
#  'area_total_calc': 9503,
#  'area_total_finished': 745,
#  'bath_3qtrs_count': 197,
#  'bldg_framing': 72,
#  'bldg_quality': 4157,
#  'city_counts': 2377,
#  'deck_type': 118,
#  'fips': 177,
#  'fireplace_count': 204,
#  'garage_stalls_count': 438,
#  'garage_yn': 11,
#  'heatingorsystemtypeid': 488,
#  'length_tax_delinq': 16,
#  'log_area_finished_living': 772,
#  'log_area_total_calc': 367,
#  'lot_size': 6448,
#  'number_of_stories': 690,
#  'pool_count': 1157,
#  'pooltypeid10': 100,
#  'pooltypeid2': 319,
#  'pooltypeid7': 94,
#  'property_age': 11982,
#  'region_city': 3115,
#  'region_county': 1834,
#  'region_neighbor': 2014,
#  'region_zip': 8053,
#  'room_count': 833,
#  'single_family_home': 247,
#  'tax_delinquency_year': 42,
#  'tax_land': 8408,
#  'tax_year': 33,
#  'total_rooms': 2615,
#  'unit_count': 517,
#  'zip_counts': 4499,
#  'zoning_land_use': 1783}

# %%
print(model.feature_importances_)
# Out:
# [1.3242681e-02 0.0000000e+00 1.4700477e-03 8.8202866e-04 5.0924905e-02
#  1.4455470e-03 1.0731349e-02 1.1641553e-01 3.2034792e-02 1.7150557e-04
#  9.1265468e-03 3.0258484e-03 6.7132181e-03 2.1683206e-03 2.4990812e-03
#  5.3656744e-03 1.6182777e-02 5.9781941e-03 7.8990564e-02 1.4173711e-02
#  1.2617910e-03 1.2250398e-03 3.9078770e-03 1.1515374e-03 2.1842459e-02
#  3.8159989e-02 2.2467230e-02 2.4672301e-02 9.8652460e-02 1.0204582e-02
#  0.0000000e+00 2.4133285e-03 0.0000000e+00 6.3334559e-03 3.1238515e-03
#  3.0625996e-04 8.4527750e-03 4.0426315e-04 1.0300135e-01 5.1451672e-04
#  1.4678428e-01 1.9600637e-04 3.2034792e-02 1.3475437e-04 0.0000000e+00
#  0.0000000e+00 3.0258484e-03 5.5114541e-02 2.9119197e-02 0.0000000e+00
#  4.4958959e-03 9.4573069e-03 0.0000000e+00]

# %%
valid_data = pd.concat([xtest,ytest], axis=1)
valid_data['predicted'] = model.predict(xtest)
valid_data['pred_diff'] = (valid_data['target'] - valid_data['predicted'])

# %%
import matplotlib.ticker as mtick
fig, ax = plt.subplots(figsize=(10,4))
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick) 
plt.ylim (-2000000,2000000)
plt.xlabel('Actual value')
plt.ylabel('Mean error')
(valid_data['pred_diff']).plot(linewidth=0.5)

# %%
fig, ax = plt.subplots(figsize=(10,4))
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick) 
plt.ylim (0,2000000)
plt.xlabel('Home value')
plt.ylabel('Mean absolute error (MAE)')
np.abs(valid_data['pred_diff']).plot(linewidth=0.5)

# %%
x=valid_data['predicted']
y=valid_data['target']
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)
plt.ylabel('Actual home value')
plt.xlabel('Predicted home value')
plt.scatter(x, y, s=2)

# %%
#  Check to see if the MAE values are different depending on home values (use +/- 1std)
std  = np.std(properties1['home_value'])
p50  = properties1['home_value'].quantile(0.50)
np.mean(np.abs( valid_data['pred_diff'].where((valid_data['target']>=p50 - std) & (valid_data['target']<=p50 + std)) ))
# Out:
# 25753.194601097657

# %%
# save the model to disk
import pickle
filename = 'final_model_100.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
import pickle
filename = 'final_model_100.sav'
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(xtest, ytest)
print(result)
